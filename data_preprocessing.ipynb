# %% [markdown]
# <a href="https://colab.research.google.com/github/louizaferiel/autism.colab/blob/main/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_set=pd.read_csv('Toddler Autism dataset July 2018 - Toddler Autism dataset July 2018 (1) - Toddler Autism dataset July 2018 - Toddler Autism dataset July 2018 (1).csv')

# %%
data_set.head()
# Out:
#    Case_No  Look_at you_when_you_call_him/her  \
# 0        1                                  0
# 1        2                                  1
# 2        3                                  1
# 3        4                                  1
# 4        5                                  1
#
#    Easy_to get_eye_contact_with_you  \
# 0                                 0
# 1                                 1
# 2                                 0
# 3                                 1
# 4                                 1
#
#    Your_child_point_to_indicate_that_s/he wants_something  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    Your_child_point_to_share_interst_with_you  Your_child_pretend  \
# ...

# %%
type(data_set)
# Out:
# pandas.core.frame.DataFrame

# %%
#data_set is a dataframe object

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 19 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Case_No                                                                                                  1054 non-null   int64
#  1   Look_at you_when_you_call_him/her                                                                        1054 non-null   int64
#  2   Easy_to get_eye_contact_with_you                                                                         1054 non-null   int64
#  3   Your_child_point_to_indicate_that_s/he wants_something                                                   1054 non-null   int64
# ...

# %%
data_set.tail()
# Out:
#       Case_No  Look_at you_when_you_call_him/her  \
# 1049     1050                                  0
# 1050     1051                                  0
# 1051     1052                                  1
# 1052     1053                                  1
# 1053     1054                                  1
#
#       Easy_to get_eye_contact_with_you  \
# 1049                                 0
# 1050                                 0
# 1051                                 0
# 1052                                 0
# 1053                                 1
#
#       Your_child_point_to_indicate_that_s/he wants_something  \
# 1049                                                  0
# 1050                                                  1
# 1051                                                  1
# 1052                                                  0
# 1053                                                  0
#
#       Your_child_point_to_share_interst_with_you  Your_child_pretend  \
# ...

# %%
#structured data (csv file)

# %%
data_set.columns
# Out:
# Index(['Case_No', 'Look_at you_when_you_call_him/her',
#        'Easy_to get_eye_contact_with_you',
#        'Your_child_point_to_indicate_that_s/he wants_something',
#        'Your_child_point_to_share_interst_with_you', 'Your_child_pretend',
#        'Your_child_follows_you_where_you_are_looking',
#        'If_you_or_someone_else_in_the_family_is_visubly_upset _does your child_signs_of_wanting_to_comfort_them',
#        'describe_your_child_first_word_as', 'Your_child_uses_simple_gesture',
#        'S/he_stares_at_nothing_with_no_apparent_porpose', 'Age_Mons',
#        'QA_Score', 'Sex', 'Ethnicity', 'Jaundice', 'Family_mem_with_ASD',
#        'Who_completed_the_test', 'ASD'],
#       dtype='object')

# %%
data_set.index
# Out:
# RangeIndex(start=0, stop=1054, step=1)

# %%
#indexing and slicing dataframe
data_set.ASD
# Out:
# 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 1049     No
# 1050    Yes
# 1051    Yes
# 1052     No
# 1053    Yes
# Name: ASD, Length: 1054, dtype: object

# %%
data_set.Ethnicity
# Out:
# 0       middle eastern
# 1       White European
# 2       middle eastern
# 3             Hispanic
# 4       White European
#              ...
# 1049    White European
# 1050             black
# 1051    middle eastern
# 1052    White European
# 1053             asian
# Name: Ethnicity, Length: 1054, dtype: object

# %%
data_set.Sex
# Out:
# 0       f
# 1       m
# 2       m
# 3       m
# 4       f
#        ..
# 1049    f
# 1050    m
# 1051    m
# 1052    m
# 1053    m
# Name: Sex, Length: 1054, dtype: object

# %%
data_set.Age_Mons
# Out:
# 0       28
# 1       36
# 2       36
# 3       24
# 4       20
#         ..
# 1049    24
# 1050    12
# 1051    18
# 1052    19
# 1053    24
# Name: Age_Mons, Length: 1054, dtype: int64

# %%
data_set.sort_values(by='Sex')
# Out:
#       Case_No  Look_at you_when_you_call_him/her  \
# 0           1                                  0
# 558       559                                  0
# 551       552                                  0
# 549       550                                  0
# 545       546                                  0
# ...       ...                                ...
# 515       516                                  1
# 516       517                                  1
# 158       159                                  0
# 519       520                                  1
# 1053     1054                                  1
#
#       Easy_to get_eye_contact_with_you  \
# 0                                    0
# 558                                  0
# 551                                  0
# 549                                  1
# 545                                  0
# ...                                ...
# 515                                  0
# 516                                  0
# ...

# %%
data_set.groupby('Sex').mean()
# Out:
#         Case_No  Look_at you_when_you_call_him/her  \
# Sex
# f    496.579937                           0.479624
# m    540.919728                           0.600000
#
#      Easy_to get_eye_contact_with_you  \
# Sex
# f                            0.398119
# m                            0.470748
#
#      Your_child_point_to_indicate_that_s/he wants_something  \
# Sex
# f                                             0.354232
# m                                             0.421769
#
#      Your_child_point_to_share_interst_with_you  Your_child_pretend  \
# Sex
# f                                      0.432602            0.426332
# m                                      0.546939            0.567347
#
#      Your_child_follows_you_where_you_are_looking  \
# Sex
# f                                        0.557994
# m                                        0.585034
#
#      If_you_or_someone_else_in_the_family_is_visubly_upset _does your child_signs_of_wanting_to_comfort_them  \
# Sex
# ...

# %%
data_set.groupby('Look_at you_when_you_call_him/her').mean()
# Out:
#                                       Case_No  \
# Look_at you_when_you_call_him/her
# 0                                  509.926087
# 1                                  541.109428
#
#                                    Easy_to get_eye_contact_with_you  \
# Look_at you_when_you_call_him/her
# 0                                                          0.186957
# 1                                                          0.651515
#
#                                    Your_child_point_to_indicate_that_s/he wants_something  \
# Look_at you_when_you_call_him/her
# 0                                                                           0.265217
# 1                                                                           0.506734
#
#                                    Your_child_point_to_share_interst_with_you  \
# Look_at you_when_you_call_him/her
# 0                                                                    0.371739
# ...

# %%
data_set.isnull
# Out:
# <bound method DataFrame.isnull of       Case_No  Look_at you_when_you_call_him/her  \
# 0           1                                  0
# 1           2                                  1
# 2           3                                  1
# 3           4                                  1
# 4           5                                  1
# ...       ...                                ...
# 1049     1050                                  0
# 1050     1051                                  0
# 1051     1052                                  1
# 1052     1053                                  1
# 1053     1054                                  1
#
#       Easy_to get_eye_contact_with_you  \
# 0                                    0
# 1                                    1
# 2                                    0
# 3                                    1
# 4                                    1
# ...                                ...
# 1049                                 0
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 19 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Case_No                                                                                                  1054 non-null   int64
#  1   Look_at you_when_you_call_him/her                                                                        1054 non-null   int64
#  2   Easy_to get_eye_contact_with_you                                                                         1054 non-null   int64
#  3   Your_child_point_to_indicate_that_s/he wants_something                                                   1054 non-null   int64
# ...

# %%
data_set.describe()
# Out:
#            Case_No  Look_at you_when_you_call_him/her  \
# count  1054.000000                        1054.000000
# mean    527.500000                           0.563567
# std     304.407895                           0.496178
# min       1.000000                           0.000000
# 25%     264.250000                           0.000000
# 50%     527.500000                           1.000000
# 75%     790.750000                           1.000000
# max    1054.000000                           1.000000
#
#        Easy_to get_eye_contact_with_you  \
# count                       1054.000000
# mean                           0.448767
# std                            0.497604
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            1.000000
# max                            1.000000
#
#        Your_child_point_to_indicate_that_s/he wants_something  \
# ...

# %%
#print maximum number or maximum item inside a column
data_set.loc[data_set['Easy_to get_eye_contact_with_you'].argmax()]
# Out:
# Case_No                                                                                                                 2
# Look_at you_when_you_call_him/her                                                                                       1
# Easy_to get_eye_contact_with_you                                                                                        1
# Your_child_point_to_indicate_that_s/he wants_something                                                                  0
# Your_child_point_to_share_interst_with_you                                                                              0
# Your_child_pretend                                                                                                      0
# Your_child_follows_you_where_you_are_looking                                                                            1
# If_you_or_someone_else_in_the_family_is_visubly_upset _does your child_signs_of_wanting_to_comfort_them                 1
# ...

# %%
#print the min
data_set.loc[data_set['Easy_to get_eye_contact_with_you'].argmin()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b1af1a5bbb57> in <module>
#       1 #print the min
# ----> 2 data_set.loc[data_set['Easy_to get_eye_contact_with_you'].argmin()]
#
# NameError: name 'data_set' is not defined

# %% [markdown]
# Visualization

# %% [markdown]
# EDA

# %%
#numpy. arange ( [ start , ] stop , [ step , ] dtype=None , * , like=None ) 
#Renvoie des valeurs régulièrement espacées dans un intervalle donné.

# %%
#show data un bar plots
x=data_set['Sex']
y=data_set['Age_Mons']
plt.bar(x,y)
#plt.bar(x,y)
#range len de x pour parcourrir chaque element de x jusqu'a la fin
plt.title('age of children and their sex')
plt.xlabel('Sex of children')
plt.ylabel('age in month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-603409a10e40> in <module>
#       1 #show data un bar plots
# ----> 2 x=data_set['Sex']
#       3 y=data_set['Age_Mons']
#       4 plt.bar(x,y)
#       5 #plt.bar(x,y)
#
# NameError: name 'data_set' is not defined

# %%
#histograms
#frequency distibution of values
plt.hist(y)
# Out:
# (array([104.,  44.,  49.,  34.,  55., 132.,  65., 121.,  66., 384.]),
#  array([12. , 14.4, 16.8, 19.2, 21.6, 24. , 26.4, 28.8, 31.2, 33.6, 36. ]),
#  <a list of 10 Patch objects>)

# %%
#advanced visualisation using seaborn
data_set.plot()

# %%
data_set.Case_No.plot()

# %%
test1=pd.Series(data_set['Case_No'],index=data_set['QA_Score'])
test1.plot.bar(color='g',alpha=1)
#alpha est 1 parametre de visibilité de couleur RGB borné entre 0 et 1

# %%
test1.plot.barh(color='y',alpha=1)

# %%
test2=pd.Series(data_set['Case_No'],index=data_set['Your_child_point_to_share_interst_with_you'])
test2.plot.barh(color='b',alpha=1)

# %%
test3=pd.Series(data_set['Your_child_uses_simple_gesture'])
test3.plot.hist()
